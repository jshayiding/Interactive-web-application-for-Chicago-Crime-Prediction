# %%
import pandas as pd
import numpy as np
import geopandas as gpd

# %%
house_df = pd.read_excel('real_eastate_data_main.xlsx')
house_df.head(5)
# Out:
#                           Region  2012-02-01 00:00:00  2012-03-01 00:00:00  \
# 0         Chicago, IL metro area                 88.4                 93.3
# 1                    Chicago, IL                 95.1                103.6
# 2      Chicago, IL - Albany Park                 76.8                 77.9
# 3    Chicago, IL - Andersonville                193.4                169.2
# 4  Chicago, IL - Arcadia Terrace                 82.3                 62.3
#
#    2012-04-01 00:00:00  2012-05-01 00:00:00  2012-06-01 00:00:00  \
# 0                 97.6                102.0                110.7
# 1                120.4                130.6                150.8
# 2                 80.9                 98.4                109.8
# 3                157.3                156.8                175.4
# 4                 62.6                 62.6                 60.1
#
#    2012-07-01 00:00:00  2012-08-01 00:00:00  2012-09-01 00:00:00  \
# ...

# %%
# house_df.groupby('Median Sale Price').size().sort_values(ascending=False).reset_index().head()

# %% [markdown]
# ### geomap data preprocessing

# %%
chiMap = gpd.read_file('chiNeighborhood.geojson')
chiMap.head(5)
# Out:
#             pri_neigh           sec_neigh     shape_area     shape_len  \
# 0     Grand Boulevard         BRONZEVILLE  48492503.1554  28196.837157
# 1        Printers Row        PRINTERS ROW  2162137.97139   6864.247156
# 2       United Center       UNITED CENTER  32520512.7053  23101.363745
# 3  Sheffield & DePaul  SHEFFIELD & DEPAUL  10482592.2987  13227.049745
# 4       Humboldt Park       HUMBOLDT PARK  125010425.593  46126.751351
#
#                                             geometry
# 0  (POLYGON ((-87.60670812560372 41.8168137713739...
# 1  (POLYGON ((-87.62760697485348 41.8743709778537...
# 2  (POLYGON ((-87.66706868914602 41.8888518776954...
# 3  (POLYGON ((-87.65833494805533 41.9216614422918...
# 4  (POLYGON ((-87.74059567509266 41.8878231689323...
